# %%
import numpy as np
import pandas as pd
import requests
import json

URL="https://uinames.com/api/?amount=500"
response = requests.get(URL)
results = response.json()
results
# Out:
# [{'name': 'Bruno',
#   'surname': 'Markovič',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Remus',
#   'surname': 'Tatomirescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Miroslav',
#   'surname': 'Markoš',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Σοφία',
#   'surname': 'Δαμασκηνός',
#   'gender': 'female',
#   'region': 'Greece'},
#  {'name': 'Colin', 'surname': 'Leroux', 'gender': 'male', 'region': 'France'},
#  {'name': 'Peter',
#   'surname': 'Burton',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Mattéo',
#   'surname': 'Gauthier',
#   'gender': 'male',
#   'region': 'France'},
#  {'name': 'Sanja',
#   'surname': 'Nadarević',
#   'gender': 'female',
#   'region': 'Bosnia and Herzegovina'},
#  {'name': 'Ica',
#   'surname': 'Agaparian',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Florica',
#   'surname': 'Ciucurescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Daniel',
#   'surname': 'Holland',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Γλαύκος',
#   'surname': 'Μαρκόπουλος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Jolana',
#   'surname': 'Král',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'René', 'surname': 'Filip', 'gender': 'male', 'region': 'Slovakia'},
#  {'name': 'Veniamin',
#   'surname': 'Șerb',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Lucas',
#   'surname': 'Robb',
#   'gender': 'male',
#   'region': 'New Zealand'},
#  {'name': 'Jaya', 'surname': 'Bhatt', 'gender': 'female', 'region': 'Nepal'},
#  {'name': 'Dorian',
#   'surname': 'Gheorghe',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Maricica',
#   'surname': 'Țăranu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Metod', 'surname': 'Maslo', 'gender': 'male', 'region': 'Slovakia'},
#  {'name': 'Clementina',
#   'surname': 'Petrașcu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Jordan',
#   'surname': 'Deprez',
#   'gender': 'male',
#   'region': 'Belgium'},
#  {'name': 'Emanuela',
#   'surname': 'Trașcă',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Brayden',
#   'surname': 'Bouchard',
#   'gender': 'male',
#   'region': 'Canada'},
#  {'name': 'Israel', 'surname': 'Flores', 'gender': 'male', 'region': 'Mexico'},
#  {'name': 'Tánczos',
#   'surname': 'Ibolya',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Madhav', 'surname': 'Chandra', 'gender': 'male', 'region': 'Nepal'},
#  {'name': 'Гена', 'surname': 'Румянцев', 'gender': 'male', 'region': 'Russia'},
#  {'name': 'Lucrețiu',
#   'surname': 'Dinescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Maya',
#   'surname': 'Morris',
#   'gender': 'female',
#   'region': 'England'},
#  {'name': 'Cristobal',
#   'surname': 'Turcdeanu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Silvia',
#   'surname': 'Lăzărescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Camilo',
#   'surname': 'Castaño',
#   'gender': 'male',
#   'region': 'Colombia'},
#  {'name': 'Paulina',
#   'surname': 'Ciobanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Maéva',
#   'surname': 'Vincent',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Ευκτήμων',
#   'surname': 'Χριστόπουλος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Blažej',
#   'surname': 'Masarik',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Phùng', 'surname': 'Thiệu', 'gender': 'male', 'region': 'Vietnam'},
#  {'name': 'Munir',
#   'surname': 'Almazov',
#   'gender': 'female',
#   'region': 'Kyrgyz Republic'},
#  {'name': 'Muhammad',
#   'surname': 'Morgan',
#   'gender': 'male',
#   'region': 'England'},
#  {'name': 'Sorina',
#   'surname': 'Jebeleanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': '',
#   'surname': 'Juan Antonio del Ángel',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Adam',
#   'surname': 'Bašić',
#   'gender': 'male',
#   'region': 'Bosnia and Herzegovina'},
#  {'name': 'Javier',
#   'surname': 'Sánchez',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Toma',
#   'surname': 'Ciucurescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Lana', 'surname': 'Payet', 'gender': 'female', 'region': 'France'},
#  {'name': 'Marie',
#   'surname': 'Perrot',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Laurenția',
#   'surname': 'Lupu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Varvara',
#   'surname': 'Negreanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Amalia',
#   'surname': 'Bordea',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Ľubor', 'surname': 'Bašo', 'gender': 'male', 'region': 'Slovakia'},
#  {'name': 'لارين',
#   'surname': 'الروقي',
#   'gender': 'female',
#   'region': 'Saudi Arabia'},
#  {'name': 'Dumitra',
#   'surname': 'Tăriceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Marisol de',
#   'surname': 'Jesús',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Mărioara',
#   'surname': 'Bejenaru',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Robbe De',
#   'surname': 'Wilde',
#   'gender': 'male',
#   'region': 'Belgium'},
#  {'name': '尹', 'surname': '中', 'gender': 'male', 'region': 'China'},
#  {'name': 'Лиляна',
#   'surname': 'ПАВЛОВ',
#   'gender': 'female',
#   'region': 'Bulgaria'},
#  {'name': 'Yaren',
#   'surname': 'Coşkun',
#   'gender': 'female',
#   'region': 'Turkey'},
#  {'name': 'Andrej', 'surname': 'Hús', 'gender': 'male', 'region': 'Slovakia'},
#  {'name': 'Δάμασος',
#   'surname': 'Καζαντζής',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Cristobal',
#   'surname': 'Preoteasa',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Melina',
#   'surname': 'Văcăroiu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Kaleb',
#   'surname': 'Fraser',
#   'gender': 'male',
#   'region': 'New Zealand'},
#  {'name': 'Cornel', 'surname': 'Șoitu', 'gender': 'male', 'region': 'Romania'},
#  {'name': '薛', 'surname': '娟', 'gender': 'female', 'region': 'China'},
#  {'name': 'Ruben', 'surname': 'Smets', 'gender': 'male', 'region': 'Belgium'},
#  {'name': 'Aurică',
#   'surname': 'Esinencu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Regína',
#   'surname': 'Janko',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Jana', 'surname': 'Lucan', 'gender': 'female', 'region': 'Romania'},
#  {'name': 'Constantina',
#   'surname': 'Iacobescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Kádas', 'surname': 'Áron', 'gender': 'male', 'region': 'Hungary'},
#  {'name': 'Aurora',
#   'surname': 'Hernández',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Estelle',
#   'surname': 'Verstraete',
#   'gender': 'female',
#   'region': 'Belgium'},
#  {'name': 'Lư', 'surname': 'Dung', 'gender': 'female', 'region': 'Vietnam'},
#  {'name': 'Simona',
#   'surname': 'Dinulescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Nyírő', 'surname': 'Dezső', 'gender': 'male', 'region': 'Hungary'},
#  {'name': 'Balogh',
#   'surname': 'Tünde',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': '李', 'surname': '奴', 'gender': 'female', 'region': 'China'},
#  {'name': 'Nae', 'surname': 'Murgoci', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'George',
#   'surname': 'Hamilton',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Benjamín',
#   'surname': 'Murín',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Claudia',
#   'surname': 'Sierra',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Lăcrămioara',
#   'surname': 'Timofti',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': '闫', 'surname': '榕', 'gender': 'male', 'region': 'China'},
#  {'name': 'Eva',
#   'surname': 'Bertrand',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Leonard',
#   'surname': 'Albrecht',
#   'gender': 'male',
#   'region': 'Germany'},
#  {'name': 'Lioara',
#   'surname': 'Begu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Saveta',
#   'surname': 'Frențiu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Διοκλής',
#   'surname': 'Ράγκος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Εχεκράτης',
#   'surname': 'Ρόκας',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Semenica',
#   'surname': 'Giulian',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'William',
#   'surname': 'Alexander',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Hannah',
#   'surname': 'Harrison',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': 'Katherine',
#   'surname': 'Weaver',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': 'Ησύχιος',
#   'surname': 'Βυζάντιος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Γεώργιος',
#   'surname': 'Κουρμούλης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Δημοφών',
#   'surname': 'Αλαφούζος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Elisaveta',
#   'surname': 'Bădescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Aleodor',
#   'surname': 'Vîlcu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Ερατοσθένης',
#   'surname': 'Παπανικολάου',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Maxim',
#   'surname': 'Hartmann',
#   'gender': 'male',
#   'region': 'Germany'},
#  {'name': 'Δαμιανός',
#   'surname': 'Αλεξόπουλος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Oto',
#   'surname': 'Brunovský',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Carl',
#   'surname': 'Simpson',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Μάξιμος',
#   'surname': 'Αθανασιάδης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Julia',
#   'surname': 'Coteanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Cole',
#   'surname': 'Kitchener',
#   'gender': 'male',
#   'region': 'New Zealand'},
#  {'name': 'Brigita',
#   'surname': 'Paško',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Macéo', 'surname': 'Caron', 'gender': 'male', 'region': 'France'},
#  {'name': 'Dida',
#   'surname': 'Papacioc',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Françoise',
#   'surname': 'Michaud',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': '汪', 'surname': '花', 'gender': 'female', 'region': 'China'},
#  {'name': 'Birgül',
#   'surname': 'Aydoğdu',
#   'gender': 'female',
#   'region': 'Turkey'},
#  {'name': 'Visarion',
#   'surname': 'Dolha',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Ricardo',
#   'surname': 'Velasco',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Javier', 'surname': 'Ávila', 'gender': 'male', 'region': 'Mexico'},
#  {'name': 'Πτολεμαίος',
#   'surname': 'Αλεξιάδης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Josephine',
#   'surname': 'Lehmann',
#   'gender': 'female',
#   'region': 'Germany'},
#  {'name': 'Carlos',
#   'surname': 'Becerra',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Chloe',
#   'surname': 'Thomas',
#   'gender': 'female',
#   'region': 'Australia'},
#  {'name': 'Liliana',
#   'surname': 'Rivera',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Karolína',
#   'surname': 'Mikulík',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Daniel', 'surname': 'Ocampo', 'gender': 'male', 'region': 'Mexico'},
#  {'name': 'Salomea',
#   'surname': 'Păcurariu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Tatiana',
#   'surname': 'Prelipceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Lelia',
#   'surname': 'Lipatti',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Mahmut', 'surname': 'Güğül', 'gender': 'male', 'region': 'Turkey'},
#  {'name': 'Sever',
#   'surname': 'Macovei',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Pauline',
#   'surname': 'Martens',
#   'gender': 'female',
#   'region': 'Belgium'},
#  {'name': 'Tibor',
#   'surname': 'Moravec',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Raul',
#   'surname': 'Adamescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Stanca',
#   'surname': 'Luchian',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Olimpia',
#   'surname': 'Manea',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Jarolím',
#   'surname': 'Maslo',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Vivaan', 'surname': 'Singhal', 'gender': 'male', 'region': 'India'},
#  {'name': 'Bárány', 'surname': 'Hugó', 'gender': 'male', 'region': 'Hungary'},
#  {'name': 'Fábián',
#   'surname': 'Csongor',
#   'gender': 'male',
#   'region': 'Hungary'},
#  {'name': 'Εχεκράτης',
#   'surname': 'Μελετόπουλος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Fanny',
#   'surname': 'Michel',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Iosif',
#   'surname': 'Ciocârlan',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Măriuca',
#   'surname': 'Cozma',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Veniamin',
#   'surname': 'Bănulescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Eusațiu',
#   'surname': 'Manea',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'ნატო',
#   'surname': 'აბულაძე',
#   'gender': 'female',
#   'region': 'Georgia'},
#  {'name': 'Alice',
#   'surname': 'Dumont',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Carina',
#   'surname': 'Eder',
#   'gender': 'female',
#   'region': 'Austria'},
#  {'name': 'Αριστομένης',
#   'surname': 'Βέργας',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Rafael',
#   'surname': 'Moreira',
#   'gender': 'male',
#   'region': 'Portugal'},
#  {'name': 'Zhaadar',
#   'surname': 'Romanov',
#   'gender': 'male',
#   'region': 'Kyrgyz Republic'},
#  {'name': 'Anastasia',
#   'surname': 'Pițurcă',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Bronislava',
#   'surname': 'Mišík',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Κέφαλος',
#   'surname': 'Κανακάρης-Ρούφος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Francisc',
#   'surname': 'Neamțu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Loredana',
#   'surname': 'Pop',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Iurie',
#   'surname': 'Brașoveanu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Agripina',
#   'surname': 'Lupu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Angela',
#   'surname': 'Vanghelie',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Yolanda',
#   'surname': 'Castrillón',
#   'gender': 'female',
#   'region': 'Colombia'},
#  {'name': 'Cecilia',
#   'surname': 'Vânătoru',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Profira',
#   'surname': 'Drăgan',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Θεοδώρητος',
#   'surname': 'Βλαβιανός',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Martín',
#   'surname': 'Arreola',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Ευκλείδης',
#   'surname': 'Μπουκουβαλαίοι',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Emily',
#   'surname': 'Price',
#   'gender': 'female',
#   'region': 'England'},
#  {'name': 'Κίμων',
#   'surname': 'Ανδρεάδης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Armando',
#   'surname': 'Correa',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Triệu', 'surname': 'Huy', 'gender': 'male', 'region': 'Vietnam'},
#  {'name': 'Draga',
#   'surname': 'Mocioni',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Ηγησίστρατος',
#   'surname': 'Βιτάλης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Etela',
#   'surname': 'Lukáč',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Σωτήριος',
#   'surname': 'Παχής',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Γεώργιος',
#   'surname': 'Δουμπιώτης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Şaziye',
#   'surname': 'Şahin',
#   'gender': 'female',
#   'region': 'Turkey'},
#  {'name': 'Emanuel',
#   'surname': 'Miculescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Paraschiva',
#   'surname': 'Bădescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Susana', 'surname': 'Cruz', 'gender': 'female', 'region': 'Spain'},
#  {'name': 'Akif', 'surname': 'Bülbül', 'gender': 'male', 'region': 'Turkey'},
#  {'name': 'Şule',
#   'surname': 'Sabuncu',
#   'gender': 'female',
#   'region': 'Turkey'},
#  {'name': 'Riccardo',
#   'surname': 'Bianco',
#   'gender': 'male',
#   'region': 'Italy'},
#  {'name': 'Ερυσίχθονας',
#   'surname': 'Παπαϊωάννου',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Marcela',
#   'surname': 'Rusu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Hayri', 'surname': 'Dikmen', 'gender': 'male', 'region': 'Turkey'},
#  {'name': 'Anica',
#   'surname': 'Olariu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Κλεισθένης',
#   'surname': 'Ζέρβας',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Anghel',
#   'surname': 'Baghiu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Demetra',
#   'surname': 'Drăgan',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Lorelei',
#   'surname': 'Văleanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': '국', 'surname': '지은', 'gender': 'female', 'region': 'Korea'},
#  {'name': 'Teona',
#   'surname': 'Manțog',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Bohumil',
#   'surname': 'Magál',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Cazimir',
#   'surname': 'Mihăileanu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Ieremia',
#   'surname': 'Mihăescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Aurora', 'surname': 'Lira', 'gender': 'female', 'region': 'Mexico'},
#  {'name': 'Victor',
#   'surname': 'Racoveanu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Maximilián',
#   'surname': 'Michalica',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Abhinav', 'surname': 'Gavde', 'gender': 'male', 'region': 'India'},
#  {'name': 'Ιάκωβος',
#   'surname': 'Κουρμούλης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Arun', 'surname': 'Kumar', 'gender': 'male', 'region': 'Nepal'},
#  {'name': 'Daciana',
#   'surname': 'Baghiu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Rogelio', 'surname': 'Muñoz', 'gender': 'male', 'region': 'Mexico'},
#  {'name': 'Ioana',
#   'surname': 'Bodiul',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Irma',
#   'surname': 'Straka',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Lorenzo',
#   'surname': 'Madrigal',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Balogh',
#   'surname': 'Daniella',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Ancuța',
#   'surname': 'Budescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Jela',
#   'surname': 'Vlnka',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Simona',
#   'surname': 'Vitali',
#   'gender': 'female',
#   'region': 'Italy'},
#  {'name': 'Manuel',
#   'surname': 'Saucedo',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Anemona',
#   'surname': 'Maluțan',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Adelaida',
#   'surname': 'Chișu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Măriuca',
#   'surname': 'Afrom',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Hilde',
#   'surname': 'Andresen',
#   'gender': 'female',
#   'region': 'Norway'},
#  {'name': 'Călin',
#   'surname': 'Negreanu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Doru',
#   'surname': 'Cosmescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Lovász',
#   'surname': 'Fruzsina',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Pătru', 'surname': 'Covaci', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Rameshwor', 'surname': 'Saud', 'gender': 'male', 'region': 'Nepal'},
#  {'name': 'Iulia',
#   'surname': 'Tăriceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Malvina',
#   'surname': 'Trașcă',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Λουκάς',
#   'surname': 'Κορωναίος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'John',
#   'surname': 'Harper',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Simion',
#   'surname': 'Trandafir',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Isabela',
#   'surname': 'Buia',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Lascăr',
#   'surname': 'Răceanu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Adrian',
#   'surname': 'Lorenz',
#   'gender': 'male',
#   'region': 'Germany'},
#  {'name': 'Timotej',
#   'surname': 'Hrušovský',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'მამუკა',
#   'surname': 'ცერცვაძე',
#   'gender': 'male',
#   'region': 'Georgia'},
#  {'name': 'Romy', 'surname': 'Haas', 'gender': 'female', 'region': 'Germany'},
#  {'name': 'Majda',
#   'surname': 'Mešić',
#   'gender': 'female',
#   'region': 'Bosnia and Herzegovina'},
#  {'name': 'Luciana',
#   'surname': 'Ivănceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Adnan', 'surname': 'Demiral', 'gender': 'male', 'region': 'Turkey'},
#  {'name': 'Carla',
#   'surname': 'Giurescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Eszenyi',
#   'surname': 'Stella',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Daria',
#   'surname': 'Brașoveanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Izidor',
#   'surname': 'Pelikán',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Tayyar', 'surname': 'Dereli', 'gender': 'male', 'region': 'Turkey'},
#  {'name': 'Lisa',
#   'surname': 'Bosman',
#   'gender': 'female',
#   'region': 'Netherlands'},
#  {'name': 'Θεαίτητος',
#   'surname': 'Αντωνοπούλου',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Stanislas',
#   'surname': 'Gauthier',
#   'gender': 'male',
#   'region': 'France'},
#  {'name': 'Alexandra',
#   'surname': 'Chudík',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Διοκλής',
#   'surname': 'Δουρέντης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Bianca',
#   'surname': 'Bercea',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Basarab',
#   'surname': 'Neacșu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'امیرعباس', 'surname': 'کابلی', 'gender': 'male', 'region': 'Iran'},
#  {'name': 'Ankita', 'surname': 'Khan', 'gender': 'female', 'region': 'India'},
#  {'name': 'Emal',
#   'surname': 'Balašević',
#   'gender': 'male',
#   'region': 'Bosnia and Herzegovina'},
#  {'name': 'Sophie',
#   'surname': 'Matterson',
#   'gender': 'female',
#   'region': 'New Zealand'},
#  {'name': 'Julieta',
#   'surname': 'Cioran',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Ευρυμέδων',
#   'surname': 'Μανιάκης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Цветана',
#   'surname': 'ПЕТКОВА',
#   'gender': 'female',
#   'region': 'Bulgaria'},
#  {'name': 'Miroslav',
#   'surname': 'Cesnak',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Benjamin',
#   'surname': 'Nelson',
#   'gender': 'male',
#   'region': 'New Zealand'},
#  {'name': 'Aristide',
#   'surname': 'Tămaș',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Lucie',
#   'surname': 'Brunet',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Garima', 'surname': 'Rajak', 'gender': 'female', 'region': 'Nepal'},
#  {'name': 'Émile',
#   'surname': 'Schneider',
#   'gender': 'male',
#   'region': 'France'},
#  {'name': 'Rafila',
#   'surname': 'Găină',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Mohamed',
#   'surname': 'Leroy',
#   'gender': 'male',
#   'region': 'Belgium'},
#  {'name': 'Παναγιώτης',
#   'surname': 'Πυλαρινός',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Monalisa',
#   'surname': 'Mailat',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Adela',
#   'surname': 'Quiroz',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Ana',
#   'surname': 'Botescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Drahoslav',
#   'surname': 'Marián',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Nina', 'surname': 'Bailly', 'gender': 'female', 'region': 'France'},
#  {'name': 'Sarah',
#   'surname': 'Allen',
#   'gender': 'female',
#   'region': 'New Zealand'},
#  {'name': 'Anton',
#   'surname': 'Nițescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Annabell',
#   'surname': 'Martin',
#   'gender': 'female',
#   'region': 'Germany'},
#  {'name': 'Vitór',
#   'surname': 'Cavalcante',
#   'gender': 'male',
#   'region': 'Brazil'},
#  {'name': 'Masuda',
#   'surname': 'Kadyrov',
#   'gender': 'female',
#   'region': 'Kyrgyz Republic'},
#  {'name': 'Gregorio',
#   'surname': 'Galván',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Schmidt',
#   'surname': 'Odett',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Helena',
#   'surname': 'Chalupka',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Bakytbek',
#   'surname': 'Kadyrov',
#   'gender': 'male',
#   'region': 'Kyrgyz Republic'},
#  {'name': 'Γρηγόριος',
#   'surname': 'Ρέντης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Robert',
#   'surname': 'Brandt',
#   'gender': 'male',
#   'region': 'Germany'},
#  {'name': 'Julia', 'surname': 'White', 'gender': 'female', 'region': 'Canada'},
#  {'name': 'Phùng', 'surname': 'Ái', 'gender': 'female', 'region': 'Vietnam'},
#  {'name': 'هستی علی', 'surname': 'پور', 'gender': 'female', 'region': 'Iran'},
#  {'name': 'Amelia',
#   'surname': 'Kennedy',
#   'gender': 'female',
#   'region': 'New Zealand'},
#  {'name': 'Hülya',
#   'surname': 'Bozkır',
#   'gender': 'female',
#   'region': 'Turkey'},
#  {'name': 'Julie',
#   'surname': 'Andreassen',
#   'gender': 'female',
#   'region': 'Norway'},
#  {'name': 'Ηγήσιππος',
#   'surname': 'Ζυγομαλάς',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Teodosia',
#   'surname': 'Văluță',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Zsolnai',
#   'surname': 'Raimond',
#   'gender': 'male',
#   'region': 'Hungary'},
#  {'name': 'Jana', 'surname': 'Hanu', 'gender': 'female', 'region': 'Romania'},
#  {'name': 'Sara',
#   'surname': 'Kastelic',
#   'gender': 'female',
#   'region': 'Slovenia'},
#  {'name': 'Μελέαγρος',
#   'surname': 'Παπάγος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Camilla',
#   'surname': 'Colombo',
#   'gender': 'female',
#   'region': 'Italy'},
#  {'name': 'Helene',
#   'surname': 'Brandt',
#   'gender': 'female',
#   'region': 'Germany'},
#  {'name': 'Esteban',
#   'surname': 'Moulin',
#   'gender': 'male',
#   'region': 'France'},
#  {'name': 'Bali', 'surname': 'Csanád', 'gender': 'male', 'region': 'Hungary'},
#  {'name': 'Cantemir',
#   'surname': 'Maluțan',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Smriti', 'surname': 'Bista', 'gender': 'female', 'region': 'Nepal'},
#  {'name': 'Carmen',
#   'surname': 'Cătunean',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Anthony',
#   'surname': 'Budge',
#   'gender': 'male',
#   'region': 'New Zealand'},
#  {'name': 'Θεόδοτος',
#   'surname': 'Καραμήτσος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Ecaterina',
#   'surname': 'Puiu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'დარეჯან',
#   'surname': 'აბულაძე',
#   'gender': 'female',
#   'region': 'Georgia'},
#  {'name': 'Bogdan',
#   'surname': 'Caraciobanu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Liam', 'surname': 'Aerts', 'gender': 'male', 'region': 'Belgium'},
#  {'name': 'Carina',
#   'surname': 'Tudose',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Ökrös', 'surname': 'Anna', 'gender': 'female', 'region': 'Hungary'},
#  {'name': 'Barbara',
#   'surname': 'Holmes',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': 'Ηριδανός',
#   'surname': 'Μαρής',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': '孙', 'surname': '胜', 'gender': 'male', 'region': 'China'},
#  {'name': 'Luisa',
#   'surname': 'Gutiérrez',
#   'gender': 'female',
#   'region': 'Spain'},
#  {'name': 'Rózsás', 'surname': 'Gyula', 'gender': 'male', 'region': 'Hungary'},
#  {'name': 'Δαμιανός',
#   'surname': 'Δράκος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Paul', 'surname': 'Pacepa', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Ayesha',
#   'surname': 'Randhawa',
#   'gender': 'female',
#   'region': 'Pakistan'},
#  {'name': 'Lili',
#   'surname': 'Caragiani',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Manuela',
#   'surname': 'Dobrescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Elena', 'surname': 'Islas', 'gender': 'female', 'region': 'Mexico'},
#  {'name': 'Pálmai', 'surname': 'Márk', 'gender': 'male', 'region': 'Hungary'},
#  {'name': 'Bekir', 'surname': 'Bülbül', 'gender': 'male', 'region': 'Turkey'},
#  {'name': 'Ruxanda',
#   'surname': 'Dobrin',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Cloé', 'surname': 'Klein', 'gender': 'female', 'region': 'France'},
#  {'name': 'Eva',
#   'surname': 'Δεσποτόπουλος',
#   'gender': 'female',
#   'region': 'Greece'},
#  {'name': 'Esther',
#   'surname': 'Correa',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Sever', 'surname': 'Seciu', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Andrés',
#   'surname': 'Ojeda',
#   'gender': 'male',
#   'region': 'Argentina'},
#  {'name': 'Catherine',
#   'surname': 'Cooper',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': 'Verónica',
#   'surname': 'Varela',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Alexander',
#   'surname': 'Renard',
#   'gender': 'male',
#   'region': 'Belgium'},
#  {'name': 'Εύδοξος',
#   'surname': 'Αρβανίτης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Lili',
#   'surname': 'Tudorache',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Valentin',
#   'surname': 'Toderaș',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Drahomír',
#   'surname': 'Hrmo',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Sara',
#   'surname': 'Cornelis',
#   'gender': 'female',
#   'region': 'Belgium'},
#  {'name': 'Aurel',
#   'surname': 'Bocoianu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Moisés', 'surname': 'Rivas', 'gender': 'male', 'region': 'Mexico'},
#  {'name': 'Назар',
#   'surname': 'Черноусов',
#   'gender': 'male',
#   'region': 'Russia'},
#  {'name': 'Zaraza',
#   'surname': 'Oanca',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Viviana',
#   'surname': 'Liiceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Alice',
#   'surname': 'Bogaert',
#   'gender': 'female',
#   'region': 'Belgium'},
#  {'name': 'Miguel', 'surname': 'Zavala', 'gender': 'male', 'region': 'Mexico'},
#  {'name': 'Jaroslav',
#   'surname': 'Vaska',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Sebastian',
#   'surname': 'Livescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Bohumila',
#   'surname': 'Medveď',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Svetlana',
#   'surname': 'Șerb',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Jessica',
#   'surname': 'Wilson',
#   'gender': 'female',
#   'region': 'Canada'},
#  {'name': '',
#   'surname': 'María Elena Torres',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Alis',
#   'surname': 'Anghelescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Eugenia',
#   'surname': 'Tudose',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Gelu', 'surname': 'Rotaru', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Karan', 'surname': 'Upreti', 'gender': 'male', 'region': 'Nepal'},
#  {'name': 'Oleg', 'surname': 'Ďurica', 'gender': 'male', 'region': 'Slovakia'},
#  {'name': 'Noemi',
#   'surname': 'Chișu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Leana',
#   'surname': 'Vîlcu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Simina',
#   'surname': 'Nottara',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Μίλων',
#   'surname': 'Παπαγεωργίου',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Katie',
#   'surname': 'Goodwin',
#   'gender': 'female',
#   'region': 'New Zealand'},
#  {'name': 'Bohuslav',
#   'surname': 'Jano',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Kamana',
#   'surname': 'Hyolmo',
#   'gender': 'female',
#   'region': 'Nepal'},
#  {'name': 'Seema', 'surname': 'Rajak', 'gender': 'female', 'region': 'Nepal'},
#  {'name': 'Nógrádi',
#   'surname': 'Kamilla',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Kalpana',
#   'surname': 'Kansakar',
#   'gender': 'female',
#   'region': 'Nepal'},
#  {'name': 'Sarita',
#   'surname': 'Prajapati',
#   'gender': 'female',
#   'region': 'Nepal'},
#  {'name': 'Akram',
#   'surname': 'Ahelluc',
#   'gender': 'male',
#   'region': 'Morocco'},
#  {'name': 'Casiana',
#   'surname': 'Albu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Szikszai',
#   'surname': 'Bálint',
#   'gender': 'male',
#   'region': 'Hungary'},
#  {'name': 'Harold',
#   'surname': 'Davis',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Bindu',
#   'surname': 'Tamrakar',
#   'gender': 'female',
#   'region': 'Nepal'},
#  {'name': 'Valentine',
#   'surname': 'Pasquier',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Pedro', 'surname': 'Mello', 'gender': 'male', 'region': 'Brazil'},
#  {'name': 'Miroslava',
#   'surname': 'Sokol',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Δημήτριος',
#   'surname': 'Ιωάννου',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Richard',
#   'surname': 'Nichols',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'محمدیاسین',
#   'surname': 'شمشیری',
#   'gender': 'male',
#   'region': 'Iran'},
#  {'name': 'Petrișor',
#   'surname': 'Burada',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Денис', 'surname': 'Жгилёв', 'gender': 'male', 'region': 'Russia'},
#  {'name': 'Teodosia',
#   'surname': 'Gruia',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Rareș',
#   'surname': 'Pascali',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Marcela',
#   'surname': 'Brediceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Riley', 'surname': 'Clark', 'gender': 'male', 'region': 'Canada'},
#  {'name': 'Andrei',
#   'surname': 'Argetoianu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Stela',
#   'surname': 'Lucaciu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Zsigmond',
#   'surname': 'Katalin',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Olav', 'surname': 'Olsen', 'gender': 'male', 'region': 'Norway'},
#  {'name': 'Nabin', 'surname': 'Sherbuja', 'gender': 'male', 'region': 'Nepal'},
#  {'name': 'Tom', 'surname': 'Jacob', 'gender': 'male', 'region': 'France'},
#  {'name': 'Nazım', 'surname': 'Avcı', 'gender': 'male', 'region': 'Turkey'},
#  {'name': 'Kathy',
#   'surname': 'Snyder',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': 'Alis',
#   'surname': 'Fiscuteanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': '顾', 'surname': '龙', 'gender': 'male', 'region': 'China'},
#  {'name': 'Dorina',
#   'surname': 'Vernescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Ann',
#   'surname': 'Schultz',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': 'Κλεομήδης',
#   'surname': 'Ζάρκος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Elias',
#   'surname': 'Teichmann',
#   'gender': 'male',
#   'region': 'Germany'},
#  {'name': 'Gerardo',
#   'surname': 'Cabrera',
#   'gender': 'male',
#   'region': 'Mexico'},
#  {'name': 'Dochia',
#   'surname': 'Băsescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': '육', 'surname': '승현', 'gender': 'male', 'region': 'Korea'},
#  {'name': 'Sorin',
#   'surname': 'Toderaș',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': '우', 'surname': '은정', 'gender': 'female', 'region': 'Korea'},
#  {'name': 'Simona',
#   'surname': 'Filimon',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Emilia',
#   'surname': 'Dolgan',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Sara',
#   'surname': 'Robertson',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': 'Zdenko',
#   'surname': 'Šimko',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Desi',
#   'surname': 'Widodo',
#   'gender': 'male',
#   'region': 'Indonesia'},
#  {'name': 'Caitlin',
#   'surname': 'Scott',
#   'gender': 'female',
#   'region': 'England'},
#  {'name': 'Florina',
#   'surname': 'Răceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Miloslava',
#   'surname': 'Plch',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Vicențiu',
#   'surname': 'Gușatu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Regína',
#   'surname': 'Filip',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Urban', 'surname': 'Rak', 'gender': 'male', 'region': 'Slovakia'},
#  {'name': 'Δάρδανος',
#   'surname': 'Γερμανός',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Györki',
#   'surname': 'Evelin',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Aglaia',
#   'surname': 'Ciupe',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'John', 'surname': 'Ziegler', 'gender': 'male', 'region': 'Germany'},
#  {'name': 'Irma',
#   'surname': 'Gallegos',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Αρχέλαος',
#   'surname': 'Χατζηιωάννου',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Ronald',
#   'surname': 'Alvarez',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Tammy',
#   'surname': 'Hanson',
#   'gender': 'female',
#   'region': 'United States'},
#  {'name': '孟', 'surname': '澜', 'gender': 'female', 'region': 'China'},
#  {'name': 'Rajan', 'surname': 'Ghale', 'gender': 'male', 'region': 'Nepal'},
#  {'name': 'Clara',
#   'surname': 'Sørensen',
#   'gender': 'female',
#   'region': 'Denmark'},
#  {'name': 'Małgorzata',
#   'surname': 'Nowak',
#   'gender': 'female',
#   'region': 'Poland'},
#  {'name': 'Ευφράνορας',
#   'surname': 'Βαμβακάς',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Lorelei',
#   'surname': 'Malcoci',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Blake',
#   'surname': 'Maxton',
#   'gender': 'male',
#   'region': 'New Zealand'},
#  {'name': 'Suzana',
#   'surname': 'Fiscuteanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Ян', 'surname': 'Соколов', 'gender': 'male', 'region': 'Russia'},
#  {'name': 'Frusina',
#   'surname': 'Cîndea',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Tiberia',
#   'surname': 'Pițurcă',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Vibhushan',
#   'surname': 'Rijal',
#   'gender': 'male',
#   'region': 'Nepal'},
#  {'name': 'Grace',
#   'surname': 'Allen',
#   'gender': 'female',
#   'region': 'New Zealand'},
#  {'name': 'Stan',
#   'surname': 'Moscopol',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Leticia',
#   'surname': 'Franco',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Alaattin',
#   'surname': 'Erdem',
#   'gender': 'male',
#   'region': 'Turkey'},
#  {'name': 'Márta', 'surname': 'Jónás', 'gender': 'male', 'region': 'Hungary'},
#  {'name': 'Logan',
#   'surname': 'Lambert',
#   'gender': 'male',
#   'region': 'Belgium'},
#  {'name': '中村', 'surname': '拓也', 'gender': 'male', 'region': 'Japan'},
#  {'name': 'Anabela',
#   'surname': 'Paleru',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Despina',
#   'surname': 'Sabău',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Erős',
#   'surname': 'Adrienn',
#   'gender': 'female',
#   'region': 'Hungary'},
#  {'name': 'Hamza',
#   'surname': 'Hashmi',
#   'gender': 'male',
#   'region': 'Pakistan'},
#  {'name': 'Nicolaie',
#   'surname': 'Sîrghie',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Celina',
#   'surname': 'Huber',
#   'gender': 'female',
#   'region': 'Germany'},
#  {'name': 'Lugosi',
#   'surname': 'Sámuel',
#   'gender': 'male',
#   'region': 'Hungary'},
#  {'name': 'Amalia',
#   'surname': 'Trejo',
#   'gender': 'female',
#   'region': 'Mexico'},
#  {'name': 'Domnica',
#   'surname': 'Hoban',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Edward',
#   'surname': 'Cunningham',
#   'gender': 'male',
#   'region': 'United States'},
#  {'name': 'Εύβουλος',
#   'surname': 'Κούνδουρος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Veronika',
#   'surname': 'Petruška',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Simina',
#   'surname': 'Mironescu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Iacob',
#   'surname': 'Pavelescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Olympia',
#   'surname': 'Bednárik',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Ivana',
#   'surname': 'Korošec',
#   'gender': 'female',
#   'region': 'Slovenia'},
#  {'name': 'Caius',
#   'surname': 'Ciorioianu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Monika',
#   'surname': 'Mikloško',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Todor',
#   'surname': 'Popescu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Ștefan', 'surname': 'Țuțea', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Mathéo', 'surname': 'Royer', 'gender': 'male', 'region': 'France'},
#  {'name': 'Румен', 'surname': 'ИЛИЕВ', 'gender': 'male', 'region': 'Bulgaria'},
#  {'name': 'Schmidt',
#   'surname': 'Nándor',
#   'gender': 'male',
#   'region': 'Hungary'},
#  {'name': 'Bogdana',
#   'surname': 'Iepureanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Στυλιανός',
#   'surname': 'Αβραμίδης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Ιάσονας',
#   'surname': 'Δράκος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Ασκάλαφος',
#   'surname': 'Αναγνώστου',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Cecilia',
#   'surname': 'Săceanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Iridenta',
#   'surname': 'Câmpineanu',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Zoé', 'surname': 'Moreau', 'gender': 'female', 'region': 'France'},
#  {'name': 'Nicu', 'surname': 'Drumur', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Εφιάλτης',
#   'surname': 'Πανταζής',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': '顾', 'surname': '娴', 'gender': 'female', 'region': 'China'},
#  {'name': 'Przemysław',
#   'surname': 'Marciniak',
#   'gender': 'male',
#   'region': 'Poland'},
#  {'name': 'Tobias',
#   'surname': 'Christ',
#   'gender': 'male',
#   'region': 'Germany'},
#  {'name': 'Harangi',
#   'surname': 'Bence',
#   'gender': 'male',
#   'region': 'Hungary'},
#  {'name': 'Melinda',
#   'surname': 'Melichár',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Erica',
#   'surname': 'Dolgan',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Γανυμήδης',
#   'surname': 'Λαμπρόπουλος',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Troy',
#   'surname': 'Brown',
#   'gender': 'male',
#   'region': 'New Zealand'},
#  {'name': 'Huỳnh', 'surname': 'Kiên', 'gender': 'male', 'region': 'Vietnam'},
#  {'name': 'Καλλίμαχος',
#   'surname': 'Ζαΐμης',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Lina',
#   'surname': 'Rodriguez',
#   'gender': 'female',
#   'region': 'France'},
#  {'name': 'Zain', 'surname': 'Lodhi', 'gender': 'male', 'region': 'Pakistan'},
#  {'name': 'Ciprian',
#   'surname': 'Malcoci',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Татяна',
#   'surname': 'МИХАЙЛОВА',
#   'gender': 'female',
#   'region': 'Bulgaria'},
#  {'name': 'Nina',
#   'surname': 'Szymczak',
#   'gender': 'female',
#   'region': 'Poland'},
#  {'name': 'Rune', 'surname': 'Brekke', 'gender': 'male', 'region': 'Norway'},
#  {'name': 'Hồ', 'surname': 'Hiệp', 'gender': 'male', 'region': 'Vietnam'},
#  {'name': 'Matei', 'surname': 'Olariu', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Anuța',
#   'surname': 'Udrea',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Hứa', 'surname': 'Tuyền', 'gender': 'female', 'region': 'Vietnam'},
#  {'name': 'Nadir',
#   'surname': 'Nurdauletov',
#   'gender': 'female',
#   'region': 'Kyrgyz Republic'},
#  {'name': 'Nicoară',
#   'surname': 'Argetoianu',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Miroslava',
#   'surname': 'Baška',
#   'gender': 'female',
#   'region': 'Slovakia'},
#  {'name': 'Simi', 'surname': 'Buia', 'gender': 'male', 'region': 'Romania'},
#  {'name': 'Paulina',
#   'surname': 'Malcoci',
#   'gender': 'female',
#   'region': 'Romania'},
#  {'name': 'Çağ', 'surname': 'Güldalı', 'gender': 'female', 'region': 'Turkey'},
#  {'name': 'Əkbər',
#   'surname': 'İbrahimli',
#   'gender': 'male',
#   'region': 'Azerbaijan'},
#  {'name': 'Severín',
#   'surname': 'Michalko',
#   'gender': 'male',
#   'region': 'Slovakia'},
#  {'name': 'Κτησιφών',
#   'surname': 'Παχής',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Abdurrahman Yavuz',
#   'surname': '',
#   'gender': 'male',
#   'region': 'Turkey'},
#  {'name': 'Γρηγόριος',
#   'surname': 'Καλλιγάς',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': '范', 'surname': '娇', 'gender': 'female', 'region': 'China'},
#  {'name': 'Teohari',
#   'surname': 'Mailat',
#   'gender': 'male',
#   'region': 'Romania'},
#  {'name': 'Λυσικλής',
#   'surname': 'Ζυγομαλάς',
#   'gender': 'male',
#   'region': 'Greece'},
#  {'name': 'Steliana',
#   'surname': 'Râpeanu',
#   'gender': 'female',
#   'region': 'Romania'}]

# %%
people=pd.DataFrame(results)
people.head(20)
# Out:
#     gender      name                  region      surname
# 0     male     Bruno                Slovakia     Markovič
# 1     male     Remus                 Romania  Tatomirescu
# 2     male  Miroslav                Slovakia       Markoš
# 3   female     Σοφία                  Greece   Δαμασκηνός
# 4     male     Colin                  France       Leroux
# 5     male     Peter           United States       Burton
# 6     male    Mattéo                  France     Gauthier
# 7   female     Sanja  Bosnia and Herzegovina    Nadarević
# 8   female       Ica                 Romania    Agaparian
# 9   female   Florica                 Romania   Ciucurescu
# 10    male    Daniel           United States      Holland
# 11    male   Γλαύκος                  Greece  Μαρκόπουλος
# 12  female    Jolana                Slovakia         Král
# 13    male      René                Slovakia        Filip
# 14    male  Veniamin                 Romania         Șerb
# 15    male     Lucas             New Zealand         Robb
# 16  female      Jaya                   Nepal        Bhatt
# 17    male    Dorian                 Romania     Gheorghe
# 18  female  Maricica                 Romania       Țăranu
# 19    male     Metod                Slovakia        Maslo
